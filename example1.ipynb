# %%
2+3
# Out:
# 5

# %%
import numpy as np

# %%
np.__version__

# %%
import math as m

# %%
m.sqrt(16)
# Out:
# 4.0

# %%
import pandas as p

# %%
p.__version__

# %%
import pandas as pd

# %%
pd.__version__
